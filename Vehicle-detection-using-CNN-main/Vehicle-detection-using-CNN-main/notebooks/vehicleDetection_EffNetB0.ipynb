# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset/archive (5).zip')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator
import keras
from glob import glob




import warnings
from tqdm import tqdm
from PIL import Image
warnings.filterwarnings('ignore')

# %%
df=pd.DataFrame(columns=['image','label'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [image, label]
# Index: []

# %%
# for a picture containing image of vehicle label is 1.

idx=0
for name in tqdm(glob('../content/data/vehicles/*')):
    image=Image.open(name)
    img_seq=image.getdata()
    img=np.array(img_seq)
    img=np.reshape(img,(64,64,3))
    data=pd.DataFrame({'image':[img],'label':[1]},index=[idx])
    df=df.append(data)
    idx+=1
# Out:
# 100%|██████████| 8792/8792 [00:34<00:00, 253.73it/s]

# %%
# for a picture doesn't contain image of vehicle label is 0.

for name in tqdm(glob('..//content/data/non-vehicles/*')):
    image=Image.open(name)
    img_seq=image.getdata()
    img=np.array(img_seq)
    img=np.reshape(img,(64,64,3))
    data=pd.DataFrame({'image':[img],'label':[0]},index=[idx])
    df=df.append(data)
    idx+=1
# Out:
# 100%|██████████| 8968/8968 [00:37<00:00, 238.97it/s]

# %%
from sklearn.model_selection import StratifiedShuffleSplit,train_test_split
split=StratifiedShuffleSplit(n_splits=1,test_size=0.15,random_state=42)
for train_index,test_index in split.split(df,df['label']):
    train_data=df.iloc[train_index]
    class_train_data=('categorical')
    test_data=df.iloc[test_index]



# train_x,test_x,train_y,test_y=train_test_split(df['image'],df['label'],random_state=42,test_size=0.15)

# %%
train_img,train_label=train_data['image'],train_data['label']
test_img,test_label=test_data['image'],test_data['label']

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,(i%9)+1)
    ix=np.random.randint(3000)
    if(train_label.iloc[ix]==1):
        plt.title('Image no.{0} has vehicle'.format(i+1))
    elif(train_label.iloc[ix]==0):
        plt.title('Image no.{0} doesnot have vehicle'.format(i))
    plt.axis('off')
    plt.imshow(train_img.iloc[ix])
plt.show()

# %%
def change_image_dimension(data):
    data=np.reshape(data.to_list(),(len(data),64,64,3))
    return data

# %%
train_img=change_image_dimension(train_img)
test_img=change_image_dimension(test_img)
# train_img
train_img=train_img/255.0
test_img=test_img/255.0

# %%
datagen = ImageDataGenerator(
    rotation_range=10
    width_shift_range=0.1
    height_shift_range=0.1
    shear_range=0.2
    zoom_range=0.2
    horizontal_flip=True
    vertical_flip=False
)

# %%
train_label=np.array(train_label,dtype=int)
test_label=np.array(test_label,dtype=int)

# %%
train_label
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout,BatchNormalization
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.applications import EfficientNetB0
effnet = EfficientNetB0(weights = "imagenet",include_top = False,input_shape=(64,64,3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 9, 9, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 844,577
# Trainable params: 844,577
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
r=model.fit(train_img,train_label,validation_data=(test_img,test_label),epochs=30,batch_size=128)
# Out:
# Epoch 1/30
# 118/118 [==============================] - 20s 52ms/step - loss: 0.2939 - accuracy: 0.8677 - val_loss: 0.1326 - val_accuracy: 0.9516
# Epoch 2/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.1088 - accuracy: 0.9628 - val_loss: 0.1706 - val_accuracy: 0.9336
# Epoch 3/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0498 - accuracy: 0.9833 - val_loss: 0.0503 - val_accuracy: 0.9846
# Epoch 4/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0612 - accuracy: 0.9805 - val_loss: 0.0851 - val_accuracy: 0.9703
# Epoch 5/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.0283 - val_accuracy: 0.9899
# Epoch 6/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.0340 - val_accuracy: 0.9891
# Epoch 7/30
# 118/118 [==============================] - 4s 37ms/step - loss: 0.0229 - accuracy: 0.9926 - val_loss: 0.0498 - val_accuracy: 0.9872
# Epoch 8/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0153 - accuracy: 0.9948 - val_loss: 0.0192 - val_accuracy: 0.9940
# Epoch 9/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.0383 - val_accuracy: 0.9835
# Epoch 10/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.0238 - val_accuracy: 0.9925
# Epoch 11/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0178 - accuracy: 0.9939 - val_loss: 0.0185 - val_accuracy: 0.9925
# Epoch 12/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0155 - val_accuracy: 0.9940
# Epoch 13/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0118 - accuracy: 0.9958 - val_loss: 0.0257 - val_accuracy: 0.9910
# Epoch 14/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0142 - accuracy: 0.9952 - val_loss: 0.0177 - val_accuracy: 0.9947
# Epoch 15/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0228 - accuracy: 0.9917 - val_loss: 0.0176 - val_accuracy: 0.9940
# Epoch 16/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0163 - accuracy: 0.9950 - val_loss: 0.0147 - val_accuracy: 0.9944
# Epoch 17/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0258 - val_accuracy: 0.9914
# Epoch 18/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0317 - accuracy: 0.9909 - val_loss: 0.0255 - val_accuracy: 0.9899
# Epoch 19/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0213 - accuracy: 0.9931 - val_loss: 0.0265 - val_accuracy: 0.9906
# Epoch 20/30
# 118/118 [==============================] - 4s 37ms/step - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.0132 - val_accuracy: 0.9959
# Epoch 21/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0068 - accuracy: 0.9972 - val_loss: 0.0165 - val_accuracy: 0.9936
# Epoch 22/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 0.0103 - val_accuracy: 0.9951
# Epoch 23/30
# 118/118 [==============================] - 4s 36ms/step - loss: 0.0134 - accuracy: 0.9962 - val_loss: 0.0203 - val_accuracy: 0.9917
# Epoch 24/30
# 118/118 [==============================] - 4s 37ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0118 - val_accuracy: 0.9959
# Epoch 25/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0105 - val_accuracy: 0.9962
# Epoch 26/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0038 - accuracy: 0.9989 - val_loss: 0.0117 - val_accuracy: 0.9962
# Epoch 27/30
# 118/118 [==============================] - 4s 37ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0286 - val_accuracy: 0.9880
# Epoch 28/30
# 118/118 [==============================] - 4s 35ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0199 - val_accuracy: 0.9940
# Epoch 29/30
# 118/118 [==============================] - 4s 34ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0169 - val_accuracy: 0.9932
# Epoch 30/30
# 118/118 [==============================] - 4s 37ms/step - loss: 0.0253 - accuracy: 0.9930 - val_loss: 0.0271 - val_accuracy: 0.9895

# %%
plt.plot(r.history['loss'])
plt.plot(r.history['val_loss'])

# %%
plt.plot(r.history['accuracy'])
plt.plot(r.history['val_accuracy'])

# %%
plt.figure(figsize=(20,15))
for i in range(18):
    plt.subplot(3,3,(i%9)+1)
    rd_idx=np.random.randint(700)
    pred_test=model.predict(np.reshape(test_img[rd_idx],(-1,64,64,3)))
    if pred_test==1:
        plt.title('Predicted that there is vehicle in Image')
    else:
        plt.title('Predicted thet there is no vehicle in Image')
    plt.axis('off')
    plt.imshow(test_img[rd_idx])
plt.show()
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
model.save('/content/data/mymodel.h5')

# %%
from keras.saving.saving_lib import load_model
import numpy as np
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing import image
import keras.utils as image

# Load the trained model
model = tf.keras.models.load_model('/content/data/mymodel.h5')

# Function to preprocess the input image
def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(64, 64))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize the image
    return img

# Function to classify the image
def classify_image(image_path):
    img = preprocess_image(image_path)
    prediction = model.predict(img)
    if prediction[0][0] >= 0.5:
        return "Vehicle"
    else:
        return "Non-Vehicle"

# Provide the path to the image you want to test
image_path = "/content/data/non-vehicles/extra1007.png"

# Classify the image
result = classify_image(image_path)
print("Image classification result:", result)
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Image classification result: Non-Vehicle
