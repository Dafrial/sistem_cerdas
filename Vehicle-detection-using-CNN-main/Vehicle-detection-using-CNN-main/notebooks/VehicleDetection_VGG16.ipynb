# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset/archive (5).zip')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import ImageDataGenerator
import keras
from glob import glob




import warnings
from tqdm import tqdm
from PIL import Image
warnings.filterwarnings('ignore')

# %%
df=pd.DataFrame(columns=['image','label'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [image, label]
# Index: []

# %%
# for a picture containing image of vehicle label is 1.

idx=0
for name in tqdm(glob('../content/data/vehicles/*')):
    image=Image.open(name)
    img_seq=image.getdata()
    img=np.array(img_seq)
    img=np.reshape(img,(64,64,3))
    data=pd.DataFrame({'image':[img],'label':[1]},index=[idx])
    df=df.append(data)
    idx+=1
# Out:
# 100%|██████████| 8792/8792 [00:42<00:00, 207.24it/s]

# %%
# for a picture doesn't contain image of vehicle label is 0.

for name in tqdm(glob('..//content/data/non-vehicles/*')):
    image=Image.open(name)
    img_seq=image.getdata()
    img=np.array(img_seq)
    img=np.reshape(img,(64,64,3))
    data=pd.DataFrame({'image':[img],'label':[0]},index=[idx])
    df=df.append(data)
    idx+=1
# Out:
# 100%|██████████| 8968/8968 [00:38<00:00, 234.54it/s]

# %%
from sklearn.model_selection import StratifiedShuffleSplit,train_test_split
split=StratifiedShuffleSplit(n_splits=1,test_size=0.15,random_state=42)
for train_index,test_index in split.split(df,df['label']):
    train_data=df.iloc[train_index]
    class_train_data=('categorical')
    test_data=df.iloc[test_index]



# train_x,test_x,train_y,test_y=train_test_split(df['image'],df['label'],random_state=42,test_size=0.15)

# %%
train_img,train_label=train_data['image'],train_data['label']
test_img,test_label=test_data['image'],test_data['label']

# %%
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(3,3,(i%9)+1)
    ix=np.random.randint(3000)
    if(train_label.iloc[ix]==1):
        plt.title('Image no.{0} has vehicle'.format(i+1))
    elif(train_label.iloc[ix]==0):
        plt.title('Image no.{0} doesnot have vehicle'.format(i))
    plt.axis('off')
    plt.imshow(train_img.iloc[ix])
plt.show()

# %%
def change_image_dimension(data):
    data=np.reshape(data.to_list(),(len(data),64,64,3))
    return data

# %%
train_img=change_image_dimension(train_img)
test_img=change_image_dimension(test_img)
# train_img
train_img=train_img/255.0
test_img=test_img/255.0

# %%
datagen = ImageDataGenerator(
    rotation_range=10
    width_shift_range=0.1
    height_shift_range=0.1
    shear_range=0.2
    zoom_range=0.2
    horizontal_flip=True
    vertical_flip=False
)

# %%
train_label=np.array(train_label,dtype=int)
test_label=np.array(test_label,dtype=int)

# %%
train_label
# Out:
# array([0, 1, 0, ..., 0, 1, 0])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout,BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(64, 64, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 60, 60, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 10816)             0
#
#  dense (Dense)               (None, 256)               2769152
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 2,867,745
# Trainable params: 2,867,745
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
r=model.fit(train_img,train_label,validation_data=(test_img,test_label),epochs=50,batch_size=64)
# Out:
# Epoch 1/50
# 236/236 [==============================] - 19s 23ms/step - loss: 0.1974 - accuracy: 0.9173 - val_loss: 0.1152 - val_accuracy: 0.9598
# Epoch 2/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0497 - accuracy: 0.9836 - val_loss: 0.0418 - val_accuracy: 0.9857
# Epoch 3/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0452 - accuracy: 0.9841 - val_loss: 0.0359 - val_accuracy: 0.9872
# Epoch 4/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0261 - accuracy: 0.9909 - val_loss: 0.0374 - val_accuracy: 0.9884
# Epoch 5/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0209 - accuracy: 0.9926 - val_loss: 0.0297 - val_accuracy: 0.9917
# Epoch 6/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 0.0348 - val_accuracy: 0.9899
# Epoch 7/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0151 - accuracy: 0.9950 - val_loss: 0.0335 - val_accuracy: 0.9910
# Epoch 8/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0185 - accuracy: 0.9936 - val_loss: 0.0461 - val_accuracy: 0.9835
# Epoch 9/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.0268 - val_accuracy: 0.9925
# Epoch 10/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.0273 - val_accuracy: 0.9921
# Epoch 11/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0366 - val_accuracy: 0.9895
# Epoch 12/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0370 - val_accuracy: 0.9940
# Epoch 13/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0312 - accuracy: 0.9900 - val_loss: 0.0262 - val_accuracy: 0.9914
# Epoch 14/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0337 - val_accuracy: 0.9921
# Epoch 15/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0374 - val_accuracy: 0.9921
# Epoch 16/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0357 - val_accuracy: 0.9906
# Epoch 17/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0301 - val_accuracy: 0.9951
# Epoch 18/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0361 - val_accuracy: 0.9899
# Epoch 19/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0378 - val_accuracy: 0.9910
# Epoch 20/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0319 - val_accuracy: 0.9910
# Epoch 21/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0362 - val_accuracy: 0.9932
# Epoch 22/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0414 - val_accuracy: 0.9929
# Epoch 23/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0349 - val_accuracy: 0.9925
# Epoch 24/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.0644 - val_accuracy: 0.9876
# Epoch 25/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.0726 - val_accuracy: 0.9824
# Epoch 26/50
# 236/236 [==============================] - 4s 17ms/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 0.0322 - val_accuracy: 0.9929
# Epoch 27/50
# 236/236 [==============================] - 4s 18ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0310 - val_accuracy: 0.9951
# Epoch 28/50
# 236/236 [==============================] - 4s 17ms/step - loss: 8.8566e-05 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9944
# Epoch 29/50
# 236/236 [==============================] - 4s 17ms/step - loss: 2.3107e-05 - accuracy: 1.0000 - val_loss: 0.0443 - val_accuracy: 0.9947
# Epoch 30/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.3589e-05 - accuracy: 1.0000 - val_loss: 0.0472 - val_accuracy: 0.9947
# Epoch 31/50
# 236/236 [==============================] - 4s 18ms/step - loss: 1.0437e-05 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 0.9951
# Epoch 32/50
# 236/236 [==============================] - 4s 17ms/step - loss: 7.3629e-06 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9951
# Epoch 33/50
# 236/236 [==============================] - 4s 17ms/step - loss: 9.0690e-06 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9951
# Epoch 34/50
# 236/236 [==============================] - 4s 18ms/step - loss: 6.9075e-06 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 0.9951
# Epoch 35/50
# 236/236 [==============================] - 4s 17ms/step - loss: 6.3982e-06 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 0.9944
# Epoch 36/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.8262e-06 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9951
# Epoch 37/50
# 236/236 [==============================] - 4s 17ms/step - loss: 2.1345e-06 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9951
# Epoch 38/50
# 236/236 [==============================] - 4s 18ms/step - loss: 1.4520e-06 - accuracy: 1.0000 - val_loss: 0.0566 - val_accuracy: 0.9955
# Epoch 39/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.0455e-06 - accuracy: 1.0000 - val_loss: 0.0577 - val_accuracy: 0.9955
# Epoch 40/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.1420e-06 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9955
# Epoch 41/50
# 236/236 [==============================] - 4s 18ms/step - loss: 2.3442e-06 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9947
# Epoch 42/50
# 236/236 [==============================] - 4s 17ms/step - loss: 6.7115e-07 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 0.9951
# Epoch 43/50
# 236/236 [==============================] - 4s 17ms/step - loss: 6.1308e-07 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9951
# Epoch 44/50
# 236/236 [==============================] - 4s 18ms/step - loss: 5.7600e-07 - accuracy: 1.0000 - val_loss: 0.0630 - val_accuracy: 0.9951
# Epoch 45/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.2179e-06 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 0.9955
# Epoch 46/50
# 236/236 [==============================] - 4s 17ms/step - loss: 3.4877e-07 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9951
# Epoch 47/50
# 236/236 [==============================] - 4s 17ms/step - loss: 2.3225e-07 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9955
# Epoch 48/50
# 236/236 [==============================] - 4s 18ms/step - loss: 7.2715e-07 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9951
# Epoch 49/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.2349e-07 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9951
# Epoch 50/50
# 236/236 [==============================] - 4s 17ms/step - loss: 1.4983e-07 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9951

# %%
.plot(r.history['loss'])
plt.plot(r.history['valplt_loss'])

# %%
plt.plot(r.history['accuracy'])
plt.plot(r.history['val_accuracy'])

# %%
plt.figure(figsize=(20,15))
for i in range(18):
    plt.subplot(3,3,(i%9)+1)
    rd_idx=np.random.randint(700)
    pred_test=model.predict(np.reshape(test_img[rd_idx],(-1,64,64,3)))
    if pred_test==1:
        plt.title('Predicted that there is vehicle in Image')
    else:
        plt.title('Predicted thet there is no vehicle in Image')
    plt.axis('off')
    plt.imshow(test_img[rd_idx])
plt.show()
# Out:
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
model.save('/content/data/mymodel.h5')

# %%
from keras.saving.saving_lib import load_model
import numpy as np
import tensorflow as tf
from keras.preprocessing import image
from keras.preprocessing import image
import keras.utils as image

# Load the trained model
model = tf.keras.models.load_model('/content/data/mymodel.h5')

# Function to preprocess the input image
def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(64, 64))
    img = image.img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img / 255.0  # Normalize the image
    return img

# Function to classify the image
def classify_image(image_path):
    img = preprocess_image(image_path)
    prediction = model.predict(img)
    if prediction[0][0] >= 0.5:
        return "Vehicle"
    else:
        return "Non-Vehicle"

# Provide the path to the image you want to test
image_path = "/content/data/vehicles/1020.png"

# Classify the image
result = classify_image(image_path)
print("Image classification result:", result)
# Out:
# 1/1 [==============================] - 0s 82ms/step
# Image classification result: Vehicle
